# %% [markdown]
# # PEFT 进阶操作

# %% [markdown]
# ## 1. 自定义模型适配

# %%
import torch
from torch import nn
from peft import LoraConfig, get_peft_model, PeftModel
from collections import OrderedDict

# %%
net1 = nn.Sequential({
    'HaHu': nn.Linear(10, 10),
    'ReLU': nn.ReLU(),
    'HaHu2': nn.Linear(10, 2),
})
net1
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 net1 = nn.Sequential({
#       2     'HaHu': nn.Linear(10, 10),
#       3     'ReLU': nn.ReLU(),
#       4     'HaHu2': nn.Linear(10, 2),
#       5 })
#       6 net1
#
# File g:\software\anaconda\envs\pytorch\Lib\site-packages\torch\nn\modules\container.py:122, in Sequential.__init__(self, *args)
#     120 else:
#     121     for idx, module in enumerate(args):
# --> 122         self.add_module(str(idx), module)
#
# File g:\software\anaconda\envs\pytorch\Lib\site-packages\torch\nn\modules\module.py:653, in Module.add_module(self, name, module)
#     643 r"""Add a child module to the current module.
#     644
#     645 The module can be accessed as an attribute using the given name.
#    (...)    650     module (Module): child module to be added to the module.
#     651 """
#     652 if not isinstance(module, Module) and module is not None:
# --> 653     raise TypeError(f"{torch.typename(module)} is not a Module subclass")
#     654 elif not isinstance(name, str):
#     655     raise TypeError(
#     656         f"module name should be a string. Got {torch.typename(name)}"
#     657     )
#
# TypeError: dict is not a Module subclass

# %%
model = nn.Sequential(OrderedDict([
    ('conv1', nn.Conv2d(3, 64, 3)),
    ('relu1', nn.ReLU()),
    ('conv2', nn.Conv2d(64, 128, 3)),
    ('relu2', nn.ReLU()),
    ('pool', nn.MaxPool2d(2)),
    ('flatten', nn.Flatten()),
    ('fc1', nn.Linear(128 * 6 * 6, 256)),
    ('dropout', nn.Dropout(0.5)),
    ('fc2', nn.Linear(256, 10))
]))
model
# Out:
# Sequential(
#   (conv1): Conv2d(3, 64, kernel_size=(3, 3), stride=(1, 1))
#   (relu1): ReLU()
#   (conv2): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1))
#   (relu2): ReLU()
#   (pool): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (flatten): Flatten(start_dim=1, end_dim=-1)
#   (fc1): Linear(in_features=4608, out_features=256, bias=True)
#   (dropout): Dropout(p=0.5, inplace=False)
#   (fc2): Linear(in_features=256, out_features=10, bias=True)
# )

# %%
for name, param in net1.named_parameters():
    print(name)

# %%
config = LoraConfig(target_modules=["0"])

# %%
model1 = get_peft_model(net1, config)

# %%
model1

# %% [markdown]
# ## 2. 多适配器加载与切换

# %%
net2 = nn.Sequential(
    nn.Linear(10, 10),
    nn.ReLU(),
    nn.Linear(10, 2)
)
net2

# %%
config1 = LoraConfig(target_modules=["0"])
model2 = get_peft_model(net2, config1)
model2.save_pretrained("./loraA")

# %%
config2 = LoraConfig(target_modules=["2"])
model2 = get_peft_model(net2, config2)
model2.save_pretrained("./loraB")

# %%
net2 = nn.Sequential(
    nn.Linear(10, 10),
    nn.ReLU(),
    nn.Linear(10, 2)
)
net2

# %%
model2 = PeftModel.from_pretrained(net2, model_id="./loraA/", adapter_name="loraA")
model2

# %%
model2.load_adapter("./loraB/", adapter_name="loraB")
model2

# %%
model2.active_adapter

# %%
model2(torch.arange(0, 10).view(1, 10).float())

# %%
for name, param in model2.named_parameters():
    print(name, param)

# %%
for name, param in model2.named_parameters():
    if name in ["base_model.model.0.lora_A.loraA.weight", "base_model.model.0.lora_B.loraA.weight"]:
        param.data = torch.ones_like(param)

# %%
model2(torch.arange(0, 10).view(1, 10).float())

# %%
model2.set_adapter("loraB")

# %%
model2.active_adapter

# %%
model2(torch.arange(0, 10).view(1, 10).float())

# %% [markdown]
# ## 3. 禁用适配器

# %%
model2.set_adapter("loraA")

# %%
model2(torch.arange(0, 10).view(1, 10).float())

# %%
with model2.disable_adapter():
    print(model2(torch.arange(0, 10).view(1, 10).float()))
