# %%
from datasets import load_dataset
from trl import SFTConfig, SFTTrainer

# %%
dataset = load_dataset("stanfordnlp/imdb", split="train", cache_dir="G:/data_set/cache/imdb")   # 设置微调数据集，此处使用IMDB电影评论分类数据
# Out:
# ...
# train-00000-of-00001.parquet:   0%|          | 0.00/21.0M [00:00<?, ?B/s]
# test-00000-of-00001.parquet:   0%|          | 0.00/20.5M [00:00<?, ?B/s]
# unsupervised-00000-of-00001.parquet:   0%|          | 0.00/42.0M [00:00<?, ?B/s]
# ...
# Generating unsupervised split:   0%|          | 0/50000 [00:00<?, ? examples/s]

# %%
training_args = SFTConfig(  # 设置微调参数
    max_length=512,
    output_dir="G:/model_weights/output/tmp",
)

# %%
trainer = SFTTrainer(   # 设置模型，此处使用facebook的opt-350M，参数量比较小便于下载
    "facebook/opt-350m",
    train_dataset=dataset,
    args=training_args,
)
trainer.train() # 开始训练，流程和TRL一样

# %%
from transformers import pipeline

# %%
pipe = pipeline("text-generation", model="G:/model_weights/models/model/Qwen3-1.7B")
# Out:
# Loading weights:   0%|          | 0/311 [00:00<?, ?it/s]
# The tied weights mapping and config for this model specifies to tie model.embed_tokens.weight to lm_head.weight, but both are present in the checkpoints, so we will NOT tie them. You should update the config with `tie_word_embeddings=False` to silence this warning

# %%
messages = [
    {"role": "system", "content": "你是我的人工智能助手，协助我解答问题。"},
    {"role": "user", "content": "请介绍一下你自己。"},
]

# %%
pipe(messages)
# Out:
# Both `max_new_tokens` (=256) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# [{'generated_text': [{'role': 'system', 'content': '你是我的人工智能助手，协助我解答问题。'},
#    {'role': 'user', 'content': '请介绍一下你自己。'},
#    {'role': 'assistant',
#     'content': '<think>\n好的，用户让我介绍一下自己。首先，我需要确定用户的需求是什么。他们可能想要了解我的功能、能力，或者只是想确认我是否符合他们的期望。作为AI助手，我应该保持友好和专业，同时提供足够的信息。\n\n接下来，我要考虑用户可能的背景。他们可能是初次使用我的服务，或者是有特定问题需要帮助的人。因此，介绍需要简洁明了，涵盖主要功能，比如回答问题、提供信息、写文章等。同时，要强调我的局限性，比如无法进行实时互动或处理复杂任务，这样用户能清楚我的能力范围。\n\n然后，我需要组织语言，确保结构清晰。通常，介绍可以分为几个部分：自我介绍、功能介绍、局限性、感谢。这样用户能一步步了解我的各个方面。另外，使用友好的语气，避免过于技术化的术语，让不同层次的用户都能理解。\n\n还要注意用户可能的深层需求。他们可能不仅想要一个简单的介绍，还希望知道如何有效使用我，或者有什么注意事项。因此，在介绍中可以加入一些实用建议，比如如何提问、如何获取帮助等。\n\n最后，检查是否有遗漏的重要信息，比如我的语言支持、更新频率，或者是否需要用户授权等。确保'}]}]
